# %% [markdown]
# <a href="https://colab.research.google.com/github/pebble0201/pppractice/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 3233
e = 19

d = 739

message = 65

cipher = pow(message, e, n)

print("암호문 =", cipher)

plain = pow(cipher, d, n)

print("복호화 =", plain)
# Out:
# 암호문 = 232
# 복호화 = 65
